# %% [markdown]
# # Figure Skating Analysis

# %%
import numpy as np
import pandas as pd
from pandas import DataFrame, Series
import seaborn as sns

import matplotlib.pyplot as plt

# %pylab
# %matplotlib inline
# Out:
# Using matplotlib backend: Qt5Agg
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# **In which order do the categories (Men, Ladies, Pairs, Ice Skating) have the highest score in terms of total performance points?**

# %%
performance_df = pd.read_csv("performances.csv")
performance_df.head(5)
# Out:
#   performance_id                              competition  \
# 0     6e4bd41ac5  Grand Prix Final 2017 Senior and Junior
# 1     562c01c5a6  Grand Prix Final 2017 Senior and Junior
# 2     2de894c029  Grand Prix Final 2017 Senior and Junior
# 3     06e4b8b67e  Grand Prix Final 2017 Senior and Junior
# 4     72e3228deb  Grand Prix Final 2017 Senior and Junior
#
#                 program                               name nation  rank  \
# 0  ICE DANCE FREE DANCE     Anna CAPPELLINI / Luca LANOTTE    ITA     5
# 1  ICE DANCE FREE DANCE  Madison HUBBELL / Zachary DONOHUE    USA     4
# 2  ICE DANCE FREE DANCE         Madison CHOCK / Evan BATES    USA     3
# 3  ICE DANCE FREE DANCE    Maia SHIBUTANI / Alex SHIBUTANI    USA     6
# 4  ICE DANCE FREE DANCE          Tessa VIRTUE / Scott MOIR    CAN     2
#
#    starting_number  total_segment_score  total_element_score  \
# 0                1               110.99                56.01
# 1                2               112.59                57.42
# 2                3               112.79                57.25
# 3                4               109.91                54.15
# 4                5               118.33                59.66
#
#    total_component_score  total_deductions
# 0                  54.98               0.0
# 1                  55.17               0.0
# 2                  55.54               0.0
# 3                  55.76               0.0
# 4                  58.67               0.0

# %%
def typeOfSkating(row):
    if "ICE DANCE" in row["program"]:
        return "ICE DANCE"
    elif "LADIES" in row["program"]:
        return "LADIES"
    elif "MEN" in row["program"]:
        return "MEN"
    else:
        return "PAIRS"
    
performance_df["skating_type"] = performance_df.apply(lambda row: typeOfSkating(row), axis=1)
performance_df.head(5)
# Out:
#   performance_id                              competition  \
# 0     6e4bd41ac5  Grand Prix Final 2017 Senior and Junior
# 1     562c01c5a6  Grand Prix Final 2017 Senior and Junior
# 2     2de894c029  Grand Prix Final 2017 Senior and Junior
# 3     06e4b8b67e  Grand Prix Final 2017 Senior and Junior
# 4     72e3228deb  Grand Prix Final 2017 Senior and Junior
#
#                 program                               name nation  rank  \
# 0  ICE DANCE FREE DANCE     Anna CAPPELLINI / Luca LANOTTE    ITA     5
# 1  ICE DANCE FREE DANCE  Madison HUBBELL / Zachary DONOHUE    USA     4
# 2  ICE DANCE FREE DANCE         Madison CHOCK / Evan BATES    USA     3
# 3  ICE DANCE FREE DANCE    Maia SHIBUTANI / Alex SHIBUTANI    USA     6
# 4  ICE DANCE FREE DANCE          Tessa VIRTUE / Scott MOIR    CAN     2
#
#    starting_number  total_segment_score  total_element_score  \
# 0                1               110.99                56.01
# 1                2               112.59                57.42
# 2                3               112.79                57.25
# 3                4               109.91                54.15
# 4                5               118.33                59.66
#
#    total_component_score  total_deductions skating_type
# 0                  54.98               0.0    ICE DANCE
# 1                  55.17               0.0    ICE DANCE
# 2                  55.54               0.0    ICE DANCE
# 3                  55.76               0.0    ICE DANCE
# 4                  58.67               0.0    ICE DANCE

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(12, 8))
g = sns.barplot(x="skating_type", y="total_segment_score", data=performance_df, hue="skating_type", palette="muted", ci=95, n_boot=1000, order=["MEN","PAIRS","LADIES","ICE DANCE"], capsize=0.1, dodge=False)

# %% [markdown]
# **On average, how many elements are attempted for each type of skating (Men, Ladies, Pairs, Ice Skating) as well as for age categories (Senior, Junior)?**
